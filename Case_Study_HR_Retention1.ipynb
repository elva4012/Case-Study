# %% [markdown]
# <a href="https://colab.research.google.com/github/elva4012/Case-Study/blob/master/Case_Study_HR_Retention1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Retention Study - Figuring Out Which Employees May Quit
# ### Loading our Main HR Database Records

# %%
import pandas as pd

# Uncomment this line if using this notebook locally
#hr_df = pd.read_csv('./data/employee_retention/hr_data.csv') 

file_name = "https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/hr_data.csv"
hr_df = pd.read_csv(file_name)

# We use the dataframe name followed by a '.head()' to use the head function to 
# preview the first 5 records of the dataframe. If you wanted to preview the first 10, simply 
# put dataframe_name.head(10)
hr_df.head()
# Out:
#    employee_id  number_project  ...  department  salary
# 0         1003               2  ...       sales     low
# 1         1005               5  ...       sales  medium
# 2         1486               7  ...       sales  medium
# 3         1038               5  ...       sales     low
# 4         1057               2  ...       sales     low
#
# [5 rows x 9 columns]

# %%
# View the bottom 5 rows
hr_df.tail()
# Out:
#        employee_id  number_project  ...  department  salary
# 14994        87670               2  ...     support     low
# 14995        87673               2  ...     support     low
# 14996        87679               2  ...     support     low
# 14997        87681               6  ...     support     low
# 14998        87684               2  ...     support     low
#
# [5 rows x 9 columns]

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   employee_id            14999 non-null  int64
#  1   number_project         14999 non-null  int64
#  2   average_montly_hours   14999 non-null  int64
#  3   time_spend_company     14999 non-null  int64
#  4   Work_accident          14999 non-null  int64
#  5   left                   14999 non-null  int64
#  6   promotion_last_5years  14999 non-null  int64
#  7   department             14999 non-null  object
#  8   salary                 14999 non-null  object
# dtypes: int64(7), object(2)
# memory usage: 1.0+ MB

# %%
# View which columns are categorical
hr_df.select_dtypes(exclude=['int', 'float']).columns
# Out:
# Index(['department', 'salary'], dtype='object')

# %%
# Display values in categorical columns
print(hr_df['department'].unique())
print(hr_df['salary'].unique())
# Out:
# ['sales' 'accounting' 'hr' 'technical' 'support' 'management' 'IT'
#  'product_mng' 'marketing' 'RandD']
# ['low' 'medium' 'high']

# %%
# How many rows are in our dataset?
len(hr_df)
# Out:
# 14999

# %%
# What about how many columns?
len(hr_df.columns)
# Out:
# 9

# %%
hr_df.shape
# Out:
# (14999, 9)

# %% [markdown]
# ### Loading our Evaluation and Employee Satisfaction Data

# %%
# Uncomment this line if using this notebook locally
#emp_satis_eval = pd.read_excel ('./data/employee_retention/employee_satisfaction_evaluation.xlsx') 

file_name = "https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/employee_satisfaction_evaluation.xlsx"
emp_satis_eval = pd.read_excel(file_name)

emp_satis_eval.head()
# Out:
#    EMPLOYEE #  satisfaction_level  last_evaluation
# 0        1003                0.38             0.53
# 1        1005                0.80             0.86
# 2        1486                0.11             0.88
# 3        1038                0.72             0.87
# 4        1057                0.37             0.52

# %%
emp_satis_eval.shape
# Out:
# (14999, 3)

# %% [markdown]
# ### Merge or Join Tables

# %%
main_df = hr_df.set_index('employee_id').join(emp_satis_eval.set_index('EMPLOYEE #'))
main_df = main_df.reset_index()
main_df.head()
# Out:
#    employee_id  number_project  ...  satisfaction_level  last_evaluation
# 0         1003               2  ...                0.38             0.53
# 1         1005               5  ...                0.80             0.86
# 2         1486               7  ...                0.11             0.88
# 3         1038               5  ...                0.72             0.87
# 4         1057               2  ...                0.37             0.52
#
# [5 rows x 11 columns]

# %% [markdown]
# ### Is our dataset good? Are there missing values?

# %%
#main_df.isnull()
main_df[main_df.isnull().any(axis=1)]
# Out:
#        employee_id  number_project  ...  satisfaction_level  last_evaluation
# 18            3794               2  ...                 NaN              NaN
# 19            1140               5  ...                 NaN             0.89
# 33            1230               2  ...                 NaN              NaN
# 53            1340               2  ...                 NaN              NaN
# 72           22316               2  ...                 NaN              NaN
# 92            1581               2  ...                 NaN              NaN
# 107          17376               2  ...                 NaN              NaN
# 120           1739               4  ...                 NaN              NaN
# 137           1847               2  ...                 NaN              NaN
# 175          32923               4  ...                 NaN              NaN
# 191           2160               4  ...                0.92              NaN
# 352           3150               4  ...                 NaN             0.91
# 376           3250               4  ...                0.56              NaN
# 402           3405               5  ...                 NaN             1.00
# 427          78130               3  ...                 NaN             0.60
# 442           3635               5  ...                0.77              NaN
# 468           3755               5  ...                 NaN             0.92
# 543           4150               5  ...                0.89              NaN
# 892          43615               4  ...                0.74              NaN
# 1588         42185               5  ...                 NaN             0.81
# 1934         11895               4  ...                0.78              NaN
# 2343         14170               3  ...                 NaN             0.97
# 2743         16445               5  ...                0.62              NaN
# 3170         18980               5  ...                 NaN              NaN
# 3609         21580               3  ...                0.95              NaN
# 3776         22555               4  ...                 NaN             0.68
# 4122         24505               3  ...                0.86              NaN
# 4740         27950               3  ...                 NaN             0.95
# 5028         29640               4  ...                0.64              NaN
# 6453         38090               5  ...                 NaN             0.78
# 7005         41535               4  ...                0.82              NaN
# 7516         44460               4  ...                 NaN             0.97
# 8630         50960               4  ...                0.90              NaN
# 9455         55770               4  ...                 NaN             0.88
# 9901         58630               5  ...                0.92              NaN
# 10647        62595               4  ...                 NaN             0.69
# 10962        64350               5  ...                0.65              NaN
# 11575        20215               3  ...                 NaN              NaN
# 11967        70005               3  ...                0.82              NaN
# 12422        72475               5  ...                 NaN             1.00
# 12853        74880               3  ...                 NaN             0.70
# 13482        78780               3  ...                0.58              NaN
# 13925        81315               3  ...                 NaN             0.75
#
# [43 rows x 11 columns]

# %% [markdown]
# ### Let's fill in the missing blanks with the aveage values

# %%
main_df.describe()
# Out:
#         employee_id  number_project  ...  satisfaction_level  last_evaluation
# count  14999.000000    14999.000000  ...        14972.000000     14972.000000
# mean   45424.627575        3.803054  ...            0.612830         0.716125
# std    25915.900127        1.232592  ...            0.248714         0.171138
# min     1003.000000        2.000000  ...            0.090000         0.360000
# 25%    22872.500000        3.000000  ...            0.440000         0.560000
# 50%    45448.000000        4.000000  ...            0.640000         0.720000
# 75%    67480.500000        5.000000  ...            0.820000         0.870000
# max    99815.000000        7.000000  ...            1.000000         1.000000
#
# [8 rows x 9 columns]

# %%
main_df.fillna(main_df.mean(), inplace=True)
main_df.head()
# Out:
#    employee_id  number_project  ...  satisfaction_level  last_evaluation
# 0         1003               2  ...                0.38             0.53
# 1         1005               5  ...                0.80             0.86
# 2         1486               7  ...                0.11             0.88
# 3         1038               5  ...                0.72             0.87
# 4         1057               2  ...                0.37             0.52
#
# [5 rows x 11 columns]

# %%
#main_df[main_df.employee_id == 3794]
main_df.loc[main_df['employee_id'] == 3794]
# Out:
#     employee_id  number_project  ...  satisfaction_level  last_evaluation
# 18         3794               2  ...             0.61283         0.716125
#
# [1 rows x 11 columns]

# %%
main_df.head()
# Out:
#    employee_id  number_project  ...  satisfaction_level  last_evaluation
# 0         1003               2  ...                0.38             0.53
# 1         1005               5  ...                0.80             0.86
# 2         1486               7  ...                0.11             0.88
# 3         1038               5  ...                0.72             0.87
# 4         1057               2  ...                0.37             0.52
#
# [5 rows x 11 columns]

# %%
# Removing employee ID
main_df_final = main_df.drop(columns='employee_id')
main_df_final.head()
# Out:
#    number_project  average_montly_hours  ...  satisfaction_level  last_evaluation
# 0               2                   157  ...                0.38             0.53
# 1               5                   262  ...                0.80             0.86
# 2               7                   272  ...                0.11             0.88
# 3               5                   223  ...                0.72             0.87
# 4               2                   159  ...                0.37             0.52
#
# [5 rows x 10 columns]

# %%
main_df_final.groupby('department').sum()
# Out:
#              number_project  ...  last_evaluation
# department                   ...
# IT                     4683  ...       879.452250
# RandD                  3033  ...       560.446125
# accounting             2934  ...       550.706125
# hr                     2701  ...       524.006125
# management             2432  ...       456.234499
# marketing              3164  ...       613.946125
# product_mng            3434  ...       644.662250
# sales                 15634  ...      2938.236749
# support                8479  ...      1611.534499
# technical             10548  ...      1961.930624
#
# [10 rows x 8 columns]

# %%
main_df_final.groupby('department').mean()
# Out:
#              number_project  ...  last_evaluation
# department                   ...
# IT                 3.816626  ...         0.716750
# RandD              3.853875  ...         0.712130
# accounting         3.825293  ...         0.718000
# hr                 3.654939  ...         0.709075
# management         3.860317  ...         0.724182
# marketing          3.687646  ...         0.715555
# product_mng        3.807095  ...         0.714703
# sales              3.776329  ...         0.709719
# support            3.803948  ...         0.722985
# technical          3.877941  ...         0.721298
#
# [10 rows x 8 columns]

# %%
main_df_final['department'].value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: department, dtype: int64

# %%
main_df_final['left'].value_counts()
# Out:
# 0    11428
# 1     3571
# Name: left, dtype: int64

# %% [markdown]
# ### Displaying Your Correlation Matrix

# %%
import matplotlib.pyplot as plt

def plot_corr(df,size=10):
    '''Function plots a graphical correlation matrix for each pair of columns in the dataframe.

    Input:
        df: pandas DataFrame
        size: vertical and horizontal size of the plot'''

    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.legend()
    cax = ax.matshow(corr)
    fig.colorbar(cax)
    plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical')
    plt.yticks(range(len(corr.columns)), corr.columns)
    
plot_corr(main_df_final)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ## Preparing out  Dataset for ML

# %%
# Perform One Hot Encoding on Categorical Data

categorial = ['department','salary']
main_df_final = pd.get_dummies(main_df_final, columns=categorial, drop_first=True)
main_df_final.head()
# Out:
#    number_project  average_montly_hours  ...  salary_low  salary_medium
# 0               2                   157  ...           1              0
# 1               5                   262  ...           0              1
# 2               7                   272  ...           0              1
# 3               5                   223  ...           1              0
# 4               2                   159  ...           1              0
#
# [5 rows x 19 columns]

# %%
# How many columns do we now have?

len(main_df_final.columns)
# Out:
# 19

# %%
# How many employees in the dataset have left?

len(main_df_final.loc[main_df_final['left'] == 1])
# Out:
# 3571

# %%
main_df_final.head()
# Out:
#    number_project  average_montly_hours  ...  salary_low  salary_medium
# 0               2                   157  ...           1              0
# 1               5                   262  ...           0              1
# 2               7                   272  ...           0              1
# 3               5                   223  ...           1              0
# 4               2                   159  ...           1              0
#
# [5 rows x 19 columns]

# %%
main_df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   number_project          14999 non-null  int64
#  1   average_montly_hours    14999 non-null  int64
#  2   time_spend_company      14999 non-null  int64
#  3   Work_accident           14999 non-null  int64
#  4   left                    14999 non-null  int64
#  5   promotion_last_5years   14999 non-null  int64
#  6   satisfaction_level      14999 non-null  float64
#  7   last_evaluation         14999 non-null  float64
#  8   department_RandD        14999 non-null  uint8
#  9   department_accounting   14999 non-null  uint8
#  10  department_hr           14999 non-null  uint8
#  11  department_management   14999 non-null  uint8
#  12  department_marketing    14999 non-null  uint8
#  13  department_product_mng  14999 non-null  uint8
#  14  department_sales        14999 non-null  uint8
#  15  department_support      14999 non-null  uint8
#  16  department_technical    14999 non-null  uint8
#  17  salary_low              14999 non-null  uint8
#  18  salary_medium           14999 non-null  uint8
# dtypes: float64(2), int64(6), uint8(11)
# memory usage: 1.1 MB

# %% [markdown]
# ## Preparing our Dataset for Machine Learning

# %%
from sklearn.model_selection import train_test_split

# We remove the label values from our training data
X = main_df_final.drop(['left'],axis=1).values

# We assigned those label values to our Y dataset
y = main_df_final['left'].values

# %%
# Split it to a 70:30 Ratio Train:Test

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
# Normalize the data
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# fit(raw_documents[, y]): Learn a vocabulary dictionary of all tokens in the raw documents.
# fit_transform(raw_documents[, y]): Learn the vocabulary dictionary and return term-document matrix. This is equivalent to fit followed by the transform, but more efficiently implemented.

# %%
df_train = pd.DataFrame(X_train)
df_train.head()
# Out:
#          0         1         2   ...        15        16        17
# 0 -1.458211 -1.345265 -0.342716  ... -0.469606  1.023809 -0.865087
# 1  0.973582 -0.825664  0.344352  ... -0.469606 -0.976744  1.155952
# 2  0.162984 -0.965556  0.344352  ... -0.469606  1.023809 -0.865087
# 3 -1.458211  0.273492 -1.029783  ... -0.469606  1.023809 -0.865087
# 4  1.784179  0.992940  0.344352  ...  2.129443 -0.976744  1.155952
#
# [5 rows x 18 columns]

# %%
df_train.describe()
# Out:
#                  0             1   ...            16            17
# count  1.049900e+04  1.049900e+04  ...  1.049900e+04  1.049900e+04
# mean   2.398284e-16 -2.432677e-16  ... -1.569159e-16 -5.880301e-16
# std    1.000048e+00  1.000048e+00  ...  1.000048e+00  1.000048e+00
# min   -1.458211e+00 -2.104682e+00  ... -9.767443e-01 -8.650875e-01
# 25%   -6.476134e-01 -9.056025e-01  ... -9.767443e-01 -8.650875e-01
# 50%    1.629842e-01 -6.292911e-03  ... -9.767443e-01 -8.650875e-01
# 75%    9.735818e-01  8.730320e-01  ...  1.023809e+00  1.155952e+00
# max    2.594777e+00  2.172035e+00  ...  1.023809e+00  1.155952e+00
#
# [8 rows x 18 columns]

# %% [markdown]
# ## Let's Train a Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

model = LogisticRegression(solver='lbfgs')
model.fit(X_train, y_train)

predictions = model.predict(X_test)

print("Accuracy {0:.2f}%".format(100*accuracy_score(predictions, y_test)))
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# Accuracy 79.69%
# [[3225  267]
#  [ 647  361]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.88      3492
#            1       0.57      0.36      0.44      1008
#
#     accuracy                           0.80      4500
#    macro avg       0.70      0.64      0.66      4500
# weighted avg       0.78      0.80      0.78      4500

# %%
# Create Test Input 
# Enter your values here

input_data = {'number_project': [3],
              'average_montly_hours': [160],
              'time_spend_company': [5],
              'Work_accident': [0],
              'promotion_last_5years': [1],
              'last_evaluation': [0.5],
              'satisfaction_level': [0.5],
              'department_RandD': [0],
              'department_accounting': [0],
              'department_hr': [0],
              'department_management': [0],
              'department_marketing': [1],
              'department_product_mng': [0],
              'department_sales': [0],
              'department_support': [0],
              'department_technical': [0],
              'salary_low': [0],
              'salary_medium': [1]}

# Convert to pandas dataframe
input_data = pd.DataFrame(input_data)

# Transform data using sc.transform
input_data = sc.transform(input_data)

# Reshape data for input into our model predict function
input_data = input_data.reshape(1, -1)

# Run prediction for our test sameple, 0 means employee will not leave, 1 means they are likely to leave/resign
model.predict(input_data)

# print probabilities of belonging to either class
model.predict_proba(input_data)
# Out:
# array([[0.8869903, 0.1130097]])

# %% [markdown]
# ### Let's Try a Random Forest Classifer

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

model = RandomForestClassifier()
model.fit(X_train, y_train)

predictions = model.predict(X_test)
score = model.score(X_test, y_test)

print("Accuracy {0:.2f}%".format(100*accuracy_score(predictions, y_test)))
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# Accuracy 99.07%
# [[3485    7]
#  [  35  973]]
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      3492
#            1       0.99      0.97      0.98      1008
#
#     accuracy                           0.99      4500
#    macro avg       0.99      0.98      0.99      4500
# weighted avg       0.99      0.99      0.99      4500

# %%
hr_df.head()
# Out:
#    employee_id  number_project  ...  department  salary
# 0         1003               2  ...       sales     low
# 1         1005               5  ...       sales  medium
# 2         1486               7  ...       sales  medium
# 3         1038               5  ...       sales     low
# 4         1057               2  ...       sales     low
#
# [5 rows x 9 columns]

# %%
main_df_final.drop(['left'],axis=1).columns
# Out:
# Index(['number_project', 'average_montly_hours', 'time_spend_company',
#        'Work_accident', 'promotion_last_5years', 'satisfaction_level',
#        'last_evaluation', 'department_RandD', 'department_accounting',
#        'department_hr', 'department_management', 'department_marketing',
#        'department_product_mng', 'department_sales', 'department_support',
#        'department_technical', 'salary_low', 'salary_medium'],
#       dtype='object')

# %%
import pandas as pd
feature_importances = pd.DataFrame(model.feature_importances_,
                                   index = pd.DataFrame(X_train).columns,
                                    columns=['importance']).sort_values('importance',ascending=False)

feature_importances
# Out:
#     importance
# 5     0.275335
# 0     0.198373
# 2     0.190474
# 1     0.160491
# 6     0.127900
# 3     0.010113
# 16    0.009545
# 17    0.004517
# 14    0.003638
# 15    0.003619
# 13    0.003383
# 4     0.002244
# 9     0.002095
# 8     0.001996
# 7     0.001993
# 11    0.001515
# 10    0.001419
# 12    0.001350

# %% [markdown]
# ### Can Deep Learning Make a Difference?

# %%
# Use the newest version of TensorFlow 2.0
# %tensorflow_version 2.x

# %%
# If you wish to use Tensorflow 1.X run the following line and then restart runtime
# %tensorflow_version 1.x 
# You'll need to change your import statements from tensorflow.keras to keras
import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Dense(9, kernel_initializer = "uniform", activation = "relu", input_dim=18))
model.add(Dense(1, kernel_initializer = "uniform", activation = "sigmoid"))

model.compile(optimizer= "adam",loss = "binary_crossentropy",metrics = ["accuracy"])

# %%
# Display Model Summary and Show Parameters
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 9)                 171
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 10
# =================================================================
# Total params: 181
# Trainable params: 181
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Start Training Our Classifier 
batch_size = 10
epochs = 25

history = model.fit(X_train,
                    y_train,
                    batch_size = batch_size,
                    epochs = epochs,
                    verbose = 1,
                    validation_data = (X_test, y_test))

score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/25
# 1050/1050 [==============================] - 3s 2ms/step - loss: 0.4519 - accuracy: 0.7547 - val_loss: 0.3300 - val_accuracy: 0.7760
# Epoch 2/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.3166 - accuracy: 0.8573 - val_loss: 0.2723 - val_accuracy: 0.9140
# Epoch 3/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.2771 - accuracy: 0.9123 - val_loss: 0.2463 - val_accuracy: 0.9207
# Epoch 4/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.2568 - accuracy: 0.9164 - val_loss: 0.2313 - val_accuracy: 0.9238
# Epoch 5/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.2433 - accuracy: 0.9210 - val_loss: 0.2194 - val_accuracy: 0.9302
# Epoch 6/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.2328 - accuracy: 0.9273 - val_loss: 0.2100 - val_accuracy: 0.9327
# Epoch 7/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.2238 - accuracy: 0.9295 - val_loss: 0.2039 - val_accuracy: 0.9333
# Epoch 8/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.2172 - accuracy: 0.9334 - val_loss: 0.1979 - val_accuracy: 0.9358
# Epoch 9/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.2127 - accuracy: 0.9334 - val_loss: 0.1948 - val_accuracy: 0.9362
# Epoch 10/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.2090 - accuracy: 0.9377 - val_loss: 0.1931 - val_accuracy: 0.9391
# Epoch 11/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.2063 - accuracy: 0.9372 - val_loss: 0.1902 - val_accuracy: 0.9393
# Epoch 12/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.2049 - accuracy: 0.9375 - val_loss: 0.1896 - val_accuracy: 0.9404
# Epoch 13/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.2028 - accuracy: 0.9381 - val_loss: 0.1905 - val_accuracy: 0.9382
# Epoch 14/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.2023 - accuracy: 0.9379 - val_loss: 0.1896 - val_accuracy: 0.9396
# Epoch 15/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.2013 - accuracy: 0.9390 - val_loss: 0.1890 - val_accuracy: 0.9400
# Epoch 16/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.2006 - accuracy: 0.9401 - val_loss: 0.1879 - val_accuracy: 0.9402
# Epoch 17/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1996 - accuracy: 0.9388 - val_loss: 0.1886 - val_accuracy: 0.9404
# Epoch 18/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1991 - accuracy: 0.9396 - val_loss: 0.1889 - val_accuracy: 0.9393
# Epoch 19/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1988 - accuracy: 0.9414 - val_loss: 0.1890 - val_accuracy: 0.9387
# Epoch 20/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1979 - accuracy: 0.9399 - val_loss: 0.1887 - val_accuracy: 0.9353
# Epoch 21/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1975 - accuracy: 0.9398 - val_loss: 0.1885 - val_accuracy: 0.9384
# Epoch 22/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1972 - accuracy: 0.9401 - val_loss: 0.1867 - val_accuracy: 0.9411
# Epoch 23/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1965 - accuracy: 0.9402 - val_loss: 0.1863 - val_accuracy: 0.9416
# Epoch 24/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1964 - accuracy: 0.9407 - val_loss: 0.1861 - val_accuracy: 0.9404
# Epoch 25/25
# 1050/1050 [==============================] - 2s 2ms/step - loss: 0.1957 - accuracy: 0.9415 - val_loss: 0.1869 - val_accuracy: 0.9431
# Test loss: 0.1869126856327057
# Test accuracy: 0.9431111216545105

# %%
# Plotting our loss charts
import matplotlib.pyplot as plt

history_dict = history.history

loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_loss_values, label='Validation/Test Loss')
line2 = plt.plot(epochs, loss_values, label='Training Loss')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs') 
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Plotting our accuracy charts
import matplotlib.pyplot as plt

history_dict = history.history

acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']
epochs = range(1, len(loss_values) + 1)

line1 = plt.plot(epochs, val_acc_values, label='Validation/Test Accuracy')
line2 = plt.plot(epochs, acc_values, label='Training Accuracy')
plt.setp(line1, linewidth=2.0, marker = '+', markersize=10.0)
plt.setp(line2, linewidth=2.0, marker = '4', markersize=10.0)
plt.xlabel('Epochs') 
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Displaying the Classification Report and Confusion Matrix

# %%
predictions = model.predict(X_test)
predictions = (predictions > 0.5)

print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# [[3347  145]
#  [ 111  897]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96      3492
#            1       0.86      0.89      0.88      1008
#
#     accuracy                           0.94      4500
#    macro avg       0.91      0.92      0.92      4500
# weighted avg       0.94      0.94      0.94      4500

# %% [markdown]
# # Let's a Deeper Model

# %%
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Dropout

model2 = Sequential()

# Hidden Layer 1
model2.add(Dense(270, activation='relu', input_dim=18, kernel_regularizer=l2(0.01)))
model2.add(Dropout(0.3, noise_shape=None, seed=None))

# Hidden Layer 1
model2.add(Dense(180, activation='relu', input_dim=18, kernel_regularizer=l2(0.01)))
model2.add(Dropout(0.3, noise_shape=None, seed=None))

# Hidden Layer 2
model2.add(Dense(90, activation = 'relu', kernel_regularizer=l2(0.01)))
model.add(Dropout(0.3, noise_shape=None, seed=None))

model2.add(Dense(1, activation='sigmoid'))

model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 270)               5130
# _________________________________________________________________
# dropout (Dropout)            (None, 270)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 180)               48780
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 180)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 90)                16290
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 91
# =================================================================
# Total params: 70,291
# Trainable params: 70,291
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ## Training our Deeper Model

# %%
batch_size = 10
epochs = 25

history = model2.fit(X_train,
                    y_train,
                    batch_size = batch_size,
                    epochs = epochs,
                    verbose = 1,
                    validation_data = (X_test, y_test))

score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/25
# 1050/1050 [==============================] - 4s 3ms/step - loss: 0.6642 - accuracy: 0.8989 - val_loss: 0.2798 - val_accuracy: 0.9464
# Epoch 2/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2858 - accuracy: 0.9350 - val_loss: 0.2469 - val_accuracy: 0.9489
# Epoch 3/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2688 - accuracy: 0.9413 - val_loss: 0.2344 - val_accuracy: 0.9527
# Epoch 4/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2585 - accuracy: 0.9406 - val_loss: 0.2236 - val_accuracy: 0.9569
# Epoch 5/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2535 - accuracy: 0.9433 - val_loss: 0.2220 - val_accuracy: 0.9569
# Epoch 6/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2482 - accuracy: 0.9443 - val_loss: 0.2275 - val_accuracy: 0.9527
# Epoch 7/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2458 - accuracy: 0.9452 - val_loss: 0.2252 - val_accuracy: 0.9491
# Epoch 8/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2407 - accuracy: 0.9464 - val_loss: 0.2212 - val_accuracy: 0.9553
# Epoch 9/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2439 - accuracy: 0.9446 - val_loss: 0.2203 - val_accuracy: 0.9611
# Epoch 10/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2398 - accuracy: 0.9447 - val_loss: 0.2167 - val_accuracy: 0.9544
# Epoch 11/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2372 - accuracy: 0.9457 - val_loss: 0.2091 - val_accuracy: 0.9538
# Epoch 12/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2345 - accuracy: 0.9455 - val_loss: 0.2120 - val_accuracy: 0.9533
# Epoch 13/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2341 - accuracy: 0.9464 - val_loss: 0.2129 - val_accuracy: 0.9560
# Epoch 14/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2314 - accuracy: 0.9477 - val_loss: 0.2064 - val_accuracy: 0.9558
# Epoch 15/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2305 - accuracy: 0.9475 - val_loss: 0.2035 - val_accuracy: 0.9596
# Epoch 16/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2319 - accuracy: 0.9459 - val_loss: 0.2297 - val_accuracy: 0.9396
# Epoch 17/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2308 - accuracy: 0.9486 - val_loss: 0.2058 - val_accuracy: 0.9636
# Epoch 18/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2311 - accuracy: 0.9461 - val_loss: 0.1997 - val_accuracy: 0.9622
# Epoch 19/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2295 - accuracy: 0.9462 - val_loss: 0.1990 - val_accuracy: 0.9584
# Epoch 20/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2258 - accuracy: 0.9477 - val_loss: 0.1993 - val_accuracy: 0.9609
# Epoch 21/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2284 - accuracy: 0.9468 - val_loss: 0.1956 - val_accuracy: 0.9629
# Epoch 22/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2267 - accuracy: 0.9484 - val_loss: 0.2005 - val_accuracy: 0.9542
# Epoch 23/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2243 - accuracy: 0.9488 - val_loss: 0.2130 - val_accuracy: 0.9524
# Epoch 24/25
# 1050/1050 [==============================] - 3s 3ms/step - loss: 0.2266 - accuracy: 0.9481 - val_loss: 0.1954 - val_accuracy: 0.9609
# Epoch 25/25
# 1050/1050 [==============================] - 4s 4ms/step - loss: 0.2248 - accuracy: 0.9486 - val_loss: 0.1967 - val_accuracy: 0.9593
# Test loss: 0.1869126856327057
# Test accuracy: 0.9431111216545105

# %%
predictions = model2.predict(X_test)
predictions = (predictions > 0.5)

print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# [[3403   89]
#  [  94  914]]
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97      3492
#            1       0.91      0.91      0.91      1008
#
#     accuracy                           0.96      4500
#    macro avg       0.94      0.94      0.94      4500
# weighted avg       0.96      0.96      0.96      4500
